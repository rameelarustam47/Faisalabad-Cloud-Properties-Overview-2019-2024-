# %% [markdown]
# <a href="https://colab.research.google.com/github/rameelarustam47/Faisalabad-Cloud-Properties-Overview-2019-2024-/blob/main/code%20to%20find%20missing%20values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# This will open a file chooser
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5587d403-5098-4060-98c6-e36fb5f8921c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5587d403-5098-4060-98c6-e36fb5f8921c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Faisalabad_Monthly_Cirrus_COD_2019_2024.csv")

# %%
missing_values = df.isna().sum()
print(missing_values)

df.info()
# Out:
# system:index            0
# cloud_optical_depth    13
# month                   0
# year                    0
# .geo                    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   system:index         72 non-null     int64
#  1   cloud_optical_depth  59 non-null     float64
#  2   month                72 non-null     float64
#  3   year                 72 non-null     float64
#  4   .geo                 72 non-null     object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
missing_rows = df[df['cloud_optical_depth'].isna()]
print(missing_rows)
# Out:
#     system:index  cloud_optical_depth  month    year  \
# 2              2                  NaN    3.0  2019.0
# 4              4                  NaN    5.0  2019.0
# 5              5                  NaN    6.0  2019.0
# 7              7                  NaN    8.0  2019.0
# 9              9                  NaN   10.0  2019.0
# 14            14                  NaN    3.0  2020.0
# 15            15                  NaN    4.0  2020.0
# 16            16                  NaN    5.0  2020.0
# 17            17                  NaN    6.0  2020.0
# 30            30                  NaN    7.0  2021.0
# 31            31                  NaN    8.0  2021.0
# 41            41                  NaN    6.0  2022.0
# 54            54                  NaN    7.0  2023.0
#
#                                       .geo
# 2   {"type":"MultiPoint","coordinates":[]}
# 4   {"type":"MultiPoint","coordinates":[]}
# 5   {"type":"MultiPoint","coordinates":[]}
# 7   {"type":"MultiPoint","coordinates":[]}
# ...
